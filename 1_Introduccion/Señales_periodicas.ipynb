# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AxelSkrauba/Taller_Signals/blob/main/1_Introduccion/Señales_periodicas.ipynb)

# %% [markdown]
# # Señales Periódicas

# %% [markdown]
# # Senoidal

# %% [markdown]
# ## Frecuencia

# %%
import numpy as np
import matplotlib.pyplot as plt

# Vector tiempo
tiempo = np.linspace(0, 1, 100)      # Genera un array de 100 elementos entre 0 y 1
                                     # Es decir, valores equiespaciados entre el intervalo deseado
                                     # Con el range de python, se generan enteros solamente. Entre otras ventajas
frecuencia = 2

# w = 2 * pi * frecuencia
senial_t = np.sin(2 * np.pi * frecuencia * tiempo)
                                # Cómo variable dependiente, el seno de los valores
                                # Se aplica elemento a elemento. Método de numpy y sus ventajas.

# %%
# Crear el gráfico
plt.figure(figsize=(8, 6))    # Para definir un tamaño personalizado de la gráfica. No es necesario
plt.plot(tiempo, senial_t, label='s(t) = sen(w*t)')
plt.title('Gráfica de la señal')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ¿Qué pasa si en el rango de 0 a 1 uso pocos puntos? 10 por ejemplo

# %% [markdown]
# ## Amplitud + Frecuencia

# %%
def senoidal(amplitud, frecuencia, tiempo=1):
    """
    Genera una señal senoidal.
    Esta función genera una señal senoidal en función de los parámetros especificados.

    Parámetros:
    ----------
    amplitud : float
        La amplitud de la señal senoidal.
    frecuencia : float
        La frecuencia de la señal senoidal en hertz (Hz).
    tiempo : float, opcional
        La duración total de la señal en segundos. Por defecto, es 1 segundo.

    Retorna:
    -------
    tuple
        Una tupla que contiene dos arrays NumPy: el primero es el array de tiempo y el segundo es el array de valores de la señal senoidal.

    Ejemplos:
    --------
    # Generar una señal senoidal con amplitud 2, frecuencia 5 Hz y duración de 2 segundos
    tiempo, senial = senoidal(2, 5, 2)

    # Generar una señal senoidal con amplitud 1.5, frecuencia 10 Hz y duración de 0.5 segundos
    tiempo, senial = senoidal(1.5, 10, 0.5)
    """
    tiempo = np.linspace(0, tiempo, 400)
    w = 2 * np.pi * frecuencia
    senial_t = amplitud * np.sin(w * tiempo)  # Amplitud x seno
    return tiempo, senial_t

# %%
t1, s1 = senoidal(amplitud=2, frecuencia=2)

plt.figure(figsize=(8, 6))    # Para definir un tamaño personalizado de la gráfica. No es necesario
plt.plot(t1, s1, label='Señal 1')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %%
t1, s1 = senoidal(amplitud=2, frecuencia=2)
t2, s2 = senoidal(amplitud=1, frecuencia=2)

plt.figure(figsize=(8, 6))    # Para definir un tamaño personalizado de la gráfica. No es necesario
plt.plot(t1, s1, label='Señal 1')
plt.plot(t2, s2, label='Señal 2')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %%
t1, s1 = senoidal(amplitud=2, frecuencia=2)
t2, s2 = senoidal(amplitud=1, frecuencia=4)

plt.figure(figsize=(8, 6))    # Para definir un tamaño personalizado de la gráfica. No es necesario
plt.plot(t1, s1, label='Señal 1')
plt.plot(t2, s2, label='Señal 2')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ¿A cualquier frecuencia "se ve bien" la senoidal?

# %% [markdown]
# ## Interactivo

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

def plot_periodic_signal(duration, frequency, amplitude):
    t, signal = senoidal(amplitud=amplitude, frecuencia=frequency, tiempo=duration)

    plt.figure(figsize=(10, 6))
    plt.plot(t, signal)
    plt.title(f"Señal senoidal periódica: Frecuencia = {frequency} Hz, Amplitud = {amplitude}")
    plt.xlabel("Tiempo (s)")
    plt.ylabel("Amplitud")
    plt.grid(True)
    plt.show()

# %%
duration_slider = widgets.FloatSlider(value=1.0, min=0.0, max=10.0, step=0.5, description='Duración (s)')
frequency_slider = widgets.FloatSlider(value=1.0, min=0.0, max=10.0, step=0.5, description='Frecuencia (Hz)')
amplitude_slider = widgets.FloatSlider(value=1.0, min=0.0, max=5.0, step=0.5, description='Amplitud')

interactive_plot = interactive(
    plot_periodic_signal,
    duration=duration_slider,
    frequency=frequency_slider,
    amplitude=amplitude_slider
)

output = interactive_plot.children[-1]
output.layout.height = '600px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Duración (s)', max=10.0, step=0.5), FloatSlider(valu…

# %% [markdown]
# ## RMS

# %%
t, senial = senoidal(amplitud=1.5, frecuencia=1)

senial_RMS = senial*senial

plt.figure(figsize=(8, 6))
plt.plot(t, senial, label='Señal base')
plt.plot(t, senial_RMS, label='Señal RMS')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Valor Medio

# %%
t , senial = senoidal(amplitud=1, frecuencia=2)
senial_cc = senial + 0.2

# %%
plt.figure(figsize=(8, 6))
plt.plot(t, senial, label='Señal base')
plt.plot(t, senial_cc, label='Señal CC')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('S(t)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Sin componente de continua, la media es cero siempre.

# %%
senial.mean()
# Out:
# 0.0

# %%
senial_cc.mean()
# Out:
# 0.20000000000000004

# %% [markdown]
# # Señal Cuadrada

# %%
def cuadrada(amplitud, frecuencia, tiempo=1, duty_cycle=0.5):
    """
    Genera una señal cuadrada.
    Esta función genera una señal cuadrada en función de los parámetros especificados.

    Parámetros:
    ----------
    amplitud : float
        La amplitud de la señal cuadrada.
    frecuencia : float
        La frecuencia de la señal cuadrada en hertz (Hz).
    tiempo : float, opcional
        La duración total de la señal en segundos. Por defecto, es 1 segundo.
    duty_cycle : float, opcional
        El ciclo de trabajo de la señal cuadrada, en el rango de 0.0 a 1.0. Por defecto, es 0.5.

    Retorna:
    -------
    tuple
        Una tupla que contiene dos arrays NumPy: el primero es el array de tiempo y el segundo es el array de valores de la señal cuadrada.

    Ejemplos:
    --------
    # Generar una señal cuadrada con amplitud 2, frecuencia 5 Hz y duración de 2 segundos
    tiempo, senial = cuadrada(2, 5, 2)

    # Generar una señal cuadrada con amplitud 1.5, frecuencia 10 Hz, duración de 0.5 segundos y ciclo de trabajo 0.3
    tiempo, senial = cuadrada(1.5, 10, 0.5, 0.3)
    """
    tiempo = np.linspace(0, tiempo, 200)  # Crear un array de tiempo
    periodo = 1 / frecuencia  # Calcular el período
    num_pulsos = int(tiempo[-1] / periodo)  # Calcular el número de pulsos en el tiempo dado
    pulsos = np.zeros_like(tiempo)  # Crear un array para almacenar los valores de los pulsos

    for i in range(num_pulsos):
        t_inicio = i * periodo
        t_fin = t_inicio + periodo * duty_cycle
        pulsos[(tiempo >= t_inicio) & (tiempo <= t_fin)] = amplitud

    return tiempo, pulsos

# %%
t1, s1 = cuadrada(amplitud=1, frecuencia=5)

plt.figure(figsize=(8, 6))    # Para definir un tamaño personalizado de la gráfica. No es necesario
plt.plot(t1, s1, label='Señal 1')
plt.title('Gráfica de las señales')
plt.xlabel('Tiempo (segundos)')
plt.ylabel('C(t)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Referencias

# %% [markdown]
# *   [Numpy](https://numpy.org/doc/stable/index.html)
# *   [Matplotlib](https://matplotlib.org/)
# *   [Ipywidgets](https://ipywidgets.readthedocs.io/en/stable/)
